# %% [markdown]
# # Week 3 Lab — Favorite Color & Tip Calculator
#
# This notebook contains two programming exercises.  The first is a simple program that asks the user for their name and favorite color and responds with a message.  The second is a more complex program that calculates a restaurant tip and the final bill based on user input.

# %% [markdown]
# ## Part 1: Favorite Color
#
# **Goal:** Ask for a name and a favorite color, then print a friendly message.
#
# > Hint: You can concatenate strings with a plus sign, like this  "String 1 " + "String 2"

# %%
# Your code here

# %% [markdown]
# ## Part 2: Tip Calculator
#
# Write an interactive program that calculates a restaurant tip and the final bill.

# %% [markdown]
# ### Instructions
# - Display a welcome message
# - Ask for the total bill (float)
# - Ask for the desired tip percentage (int or float)
# - Convert inputs to numbers
# - Calculate tip amount and total bill
# - Display results with clear labels

# %% [markdown]
# ### Example Output
# ```
# Welcome to the Tip Calculator!
# Bill amount: 100
# Tip percent: 15
# Tip: 15.0
# Total: 115.0
# ```

# %% [markdown]
# ## Write Your Program
#
# Write your code in the cell below. Make sure to test it with different inputs to ensure it works correctly.  Follow the instructions in the problem description and example output provided above.  The comments in the code cell will help you understand what each part of the program is doing.  You can also add your own comments to explain your code.

# %%
# Step 1: Welcome Message
# Your code here


# Step 2: Get User Input
# Your code here


# Step 3: Perform Calculations
# Your code here


# Step 4: Display Results
# Your code here

# %% [markdown]
# ## Submission Checklist
# - [ ] Part 1: Favorite Color program is complete and tested
# - [ ] Part 2: Tip Calculator program is complete and tested
# - [ ] Run all cells and verify outputs
# - [ ] Stage → Commit → Sync changes in VS Code
# - [ ] Submit repo link in Blackboard
